# %%
import pandas as pd
import corner 
import numpy as np
import matplotlib.pyplot as plt

# %%
tipo =  pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[1])
tipo = np.array(tipo['type'])

type = np.array([w[31:] for w in tipo])
print(tipo)
print(type)
# Out:
# ['_lc_median_after_cbv_detrended_ACV' '_lc_median_after_cbv_detrended_ACV'
#  '_lc_median_after_cbv_detrended_ACV' ...
#  '_lc_median_after_cbv_detrended_SR' '_lc_median_after_cbv_detrended_SR'
#  '_lc_median_after_cbv_detrended_SR']
# ['ACV' 'ACV' 'ACV' ... 'SR' 'SR' 'SR']

# %%
dt1 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[3])
dt2 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[4])
dt3 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[5])
dt4 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[6])
dt5 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[7])
dt6 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[8])
dt7 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[9])
dt8 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[10])
dt9 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[11])
dt10 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[12])
dt11 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[13])
dt12 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[14])
dt13 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[15])
dt14 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[16])
dt15 = pd.read_csv('FEATURE_OUTPUT_FINAL.txt', usecols=[17])

# %%
#EMPEZANDO CON ACV
acv_good = (type=='ACV')
#print(acv_good)

# %%
dt1_acv = dt1[acv_good]
dt2_acv = dt2[acv_good]
dt3_acv = dt3[acv_good]
dt4_acv = dt4[acv_good]
dt5_acv = dt5[acv_good]
dt6_acv = dt6[acv_good]
dt7_acv = dt7[acv_good]
dt8_acv = dt8[acv_good]
dt9_acv = dt9[acv_good]
dt10_acv = dt10[acv_good]
dt11_acv = dt11[acv_good]
dt12_acv = dt12[acv_good]
dt13_acv = dt13[acv_good]
dt14_acv = dt14[acv_good]
dt15_acv = dt15[acv_good]
        
dat1 = np.array(dt1_acv)
dat2 = np.array(dt2_acv)
dat3 = np.array(dt3_acv)
dat4 = np.array(dt4_acv)
dat5 = np.array(dt5_acv)
dat6 = np.array(dt6_acv)
dat7 = np.array(dt7_acv)
dat8 = np.array(dt8_acv)
dat9 = np.array(dt9_acv)
dat10 = np.array(dt10_acv)
dat11 = np.array(dt11_acv)
dat12 = np.array(dt12_acv)
dat13 = np.array(dt13_acv)
dat14 = np.array(dt14_acv)
dat15 = np.array(dt15_acv)
        
print('Dat ACV')
#print(dat1)
# Out:
# Dat ACV

# %%
Dat_ACV = np.hstack([dat1,dat2,dat3,dat4,dat5,dat6,dat7,dat8,dat9,dat10,dat11,dat12,dat13,dat14,dat15])
#print(Dat_ACV)
#print(Dat_ACV.size)

# %%
#EMPEZANDO CEP
cep_good = (type=='CEP')

# %%
dt1_cep = dt1[cep_good]
dt2_cep = dt2[cep_good]
dt3_cep = dt3[cep_good]
dt4_cep = dt4[cep_good]
dt5_cep = dt5[cep_good]
dt6_cep = dt6[cep_good]
dt7_cep = dt7[cep_good]
dt8_cep = dt8[cep_good]
dt9_cep = dt9[cep_good]
dt10_cep = dt10[cep_good]
dt11_cep = dt11[cep_good]
dt12_cep = dt12[cep_good]
dt13_cep = dt13[cep_good]
dt14_cep = dt14[cep_good]
dt15_cep = dt15[cep_good]
        
dat1 = np.array(dt1_cep)
dat2 = np.array(dt2_cep)
dat3 = np.array(dt3_cep)
dat4 = np.array(dt4_cep)
dat5 = np.array(dt5_cep)
dat6 = np.array(dt6_cep)
dat7 = np.array(dt7_cep)
dat8 = np.array(dt8_cep)
dat9 = np.array(dt9_cep)
dat10 = np.array(dt10_cep)
dat11 = np.array(dt11_cep)
dat12 = np.array(dt12_cep)
dat13 = np.array(dt13_cep)
dat14 = np.array(dt14_cep)
dat15 = np.array(dt15_cep)

#print('Dat CEP')
Dat_CEP = np.hstack([dat1,dat2,dat3,dat4,dat5,dat6,dat7,dat8,dat9,dat10,dat11,dat12,dat13,dat14,dat15])
#print(Dat_CEP)
#print(Dat_CEP.size)

# %%
#EMPEZANDO DCEP
dcep_good = (type=='DCEP')


dt1_dcep = dt1[dcep_good]
dt2_dcep = dt2[dcep_good]
dt3_dcep = dt3[dcep_good]
dt4_dcep = dt4[dcep_good]
dt5_dcep = dt5[dcep_good]
dt6_dcep = dt6[dcep_good]
dt7_dcep = dt7[dcep_good]
dt8_dcep = dt8[dcep_good]
dt9_dcep = dt9[dcep_good]
dt10_dcep = dt10[dcep_good]
dt11_dcep = dt11[dcep_good]
dt12_dcep = dt12[dcep_good]
dt13_dcep = dt13[dcep_good]
dt14_dcep = dt14[dcep_good]
dt15_dcep = dt15[dcep_good]
        
dat1 = np.array(dt1_dcep)
dat2 = np.array(dt2_dcep)
dat3 = np.array(dt3_dcep)
dat4 = np.array(dt4_dcep)
dat5 = np.array(dt5_dcep)
dat6 = np.array(dt6_dcep)
dat7 = np.array(dt7_dcep)
dat8 = np.array(dt8_dcep)
dat9 = np.array(dt9_dcep)
dat10 = np.array(dt10_dcep)
dat11 = np.array(dt11_dcep)
dat12 = np.array(dt12_dcep)
dat13 = np.array(dt13_dcep)
dat14 = np.array(dt14_dcep)
dat15 = np.array(dt15_dcep)

#print('Dat DCEP')
Dat_DCEP = np.hstack([dat1,dat2,dat3,dat4,dat5,dat6,dat7,dat8,dat9,dat10,dat11,dat12,dat13,dat14,dat15])
#print(Dat_DCEP)
#print(Dat_DCEP.size)

# %%
#EMPEZANDO E
e_good = (type=='E')


dt1_e = dt1[e_good]
dt2_e = dt2[e_good]
dt3_e = dt3[e_good]
dt4_e = dt4[e_good]
dt5_e = dt5[e_good]
dt6_e = dt6[e_good]
dt7_e = dt7[e_good]
dt8_e = dt8[e_good]
dt9_e = dt9[e_good]
dt10_e = dt10[e_good]
dt11_e = dt11[e_good]
dt12_e = dt12[e_good]
dt13_e = dt13[e_good]
dt14_e = dt14[e_good]
dt15_e = dt15[e_good]
        
dat1 = np.array(dt1_e)
dat2 = np.array(dt2_e)
dat3 = np.array(dt3_e)
dat4 = np.array(dt4_e)
dat5 = np.array(dt5_e)
dat6 = np.array(dt6_e)
dat7 = np.array(dt7_e)
dat8 = np.array(dt8_e)
dat9 = np.array(dt9_e)
dat10 = np.array(dt10_e)
dat11 = np.array(dt11_e)
dat12 = np.array(dt12_e)
dat13 = np.array(dt13_e)
dat14 = np.array(dt14_e)
dat15 = np.array(dt15_e)

#print('Dat E')
Dat_E = np.hstack([dat1,dat2,dat3,dat4,dat5,dat6,dat7,dat8,dat9,dat10,dat11,dat12,dat13,dat14,dat15])
#print(Dat_E)
#print(Dat_E.size)

# %%
plot = corner.corner(
    Dat_ACV,color='green',
    labels=[
          r"$Amplitude$",
          r"$Autocor length$",
          r"$BeyondStd$",
          r"$CAR mean$",
          r"$CAR \sigma$",
          r"$CAR \tau$",
          r"$Con$",
          r"$Eta e$",
          r"$FluxPercentileRatioMid20$",
          r"$FluxPercentileRatioMid35$",
          r"$FluxPercentileRatioMid50$",
          r"$FluxPercentileRatioMid65$",
          r"$FluxPercentileRatioMid80$",
          r"$Freq1 harmonics amplitude 0$",
          r"$Freq1 harmonics amplitude 1$",
                  
    ],
    show_titles=True,
    title_kwargs={"fontsize": 16},
)
plt.savefig("Corner_PlotsACV01.pdf",format="pdf", bbox_inches="tight")
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ...

# %%
print('plot 2')
plot2 = corner.corner(
    Dat_CEP,color='red',
    labels=[
          r"$Amplitude$",
          r"$Autocor length$",
          r"$BeyondStd$",
          r"$CAR mean$",
          r"$CAR \sigma$",
          r"$CAR \tau$",
          r"$Con$",
          r"$Eta e$",
          r"$FluxPercentileRatioMid20$",
          r"$FluxPercentileRatioMid35$",
          r"$FluxPercentileRatioMid50$",
          r"$FluxPercentileRatioMid65$",
          r"$FluxPercentileRatioMid80$",
          r"$Freq1 harmonics amplitude 0$",
          r"$Freq1 harmonics amplitude 1$",
                  
    ],
    show_titles=True,
    title_kwargs={"fontsize": 16},
)
plt.savefig("Corner_PlotsCEP01.pdf",format="pdf", bbox_inches="tight")
# Out:
# plot 2
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ...

# %%
print('plot 3')

plot3 = corner.corner(
    Dat_DCEP,color='blue',
    labels=[
          r"$Amplitude$",
          r"$Autocor length$",
          r"$BeyondStd$",
          r"$CAR mean$",
          r"$CAR \sigma$",
          r"$CAR \tau$",
          r"$Con$",
          r"$Eta e$",
          r"$FluxPercentileRatioMid20$",
          r"$FluxPercentileRatioMid35$",
          r"$FluxPercentileRatioMid50$",
          r"$FluxPercentileRatioMid65$",
          r"$FluxPercentileRatioMid80$",
          r"$Freq1 harmonics amplitude 0$",
          r"$Freq1 harmonics amplitude 1$",
                 
    ],
    show_titles=True,
    title_kwargs={"fontsize": 16},
)

plt.savefig("Corner_PlotsDCEP01.pdf",format="pdf", bbox_inches="tight")
# Out:
# plot 3
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ...

# %%
corner.corner(Dat_ACV, fig=plot3, color='purple')
plt.savefig("ACV&DCEP_1.pdf",format="pdf", bbox_inches="tight")
#plt.show()
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ...
